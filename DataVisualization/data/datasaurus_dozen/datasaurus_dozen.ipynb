# %%
import pandas as pd
from pandas import DataFrame

df = pd.read_csv('The Datasaurus Dozen/DatasaurusDozen-wide.tsv', 
                 header=[0, 1],
                 sep='\t')
df.head()
# Out:
#         away              bullseye                circle                dino  \
#            x          y          x          y          x          y        x
# 0  32.331110  61.411101  51.203891  83.339777  55.993030  79.277264  55.3846
# 1  53.421463  26.186880  58.974470  85.499818  50.032254  79.013071  51.5385
# 2  63.920202  30.832194  51.872073  85.829738  51.288459  82.435940  46.1538
# 3  70.289506  82.533649  48.179931  85.045117  51.170537  79.165294  42.8205
# 4  34.118830  45.734551  41.683200  84.017941  44.377915  78.164628  40.7692
#
#                  dots             ...   slant_up                  star  \
#          y          x          y  ...          x          y          x
# 0  97.1795  51.147917  90.867412  ...  47.695201  95.241187  58.213608
# 1  96.0256  50.517126  89.102395  ...  44.609976  93.075835  58.196054
# 2  94.4872  50.207480  85.460047  ...  43.856381  94.085872  58.718231
# 3  91.4103  50.069482  83.057670  ...  41.578929  90.303567  57.278373
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 要求：
#
# - 绘制两个 Plot；
# - 一个绘制恐龙，并在右侧标注统计信息；
# - 一个绘制其它 12 个数据集，按照上图的方式进行排布。
